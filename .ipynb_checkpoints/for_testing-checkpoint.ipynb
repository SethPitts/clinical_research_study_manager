# %%
from testing_pandas import testing_pandas
df = testing_pandas()
df.head()
# Out:
#   ScreeningDate ScreeningTime SubjectInitials MedicalRecordNumber  Age Sex  \
# 1    2012-11-18          16:1             fai            15955814   38   M
# 2    2012-07-23          20:6             ghc            14951060   64   U
# 3    2013-07-23         19:22             hdk            15251464   75   F
# 4    2015-03-16         18:52             sca            10294538   97   U
# 5    2012-12-01           6:0             jnn            11488756    1   U
#
#   Eligible        ReasonIneligible Enrolled ReasonNotEnrolled  \
# 1        Y                      NA        N                NA
# 2        N  does_not_meet_criteria       NA                NA
# 3        N           unconsentable        N                NA
# 4        U     previously_enrolled        Y                NA
# 5        U                      NA        N                NA
#
#   ResearchAssistantInitials
# 1                       fai
# 2                       ghc
# 3                       hdk
# ...

# %%
from datetime import
